# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %%
r_consol = 'data/consolidated/'  

# Nombres de los archivos
archivos = [
    'consolidado_alimentos.xlsx',
    'consolidado_combustibles.xlsx',
    'consolidado_educacion.xlsx',
    'consolidado_salud.xlsx',
    'consolidado_vivienda.xlsx'
]

dataframes = {}

for archivo in archivos:
    dir = os.path.join(r_consol, archivo)
    dataframes[archivo] = pd.read_excel(dir)

# Mostrar las primeras filas de cada DataFrame
for archivo, df in dataframes.items():
    print(f"Datos de {archivo}:")
    print(df.head())
    print("\n")
# Out:
# Datos de consolidado_alimentos.xlsx:
#   CATEGORIA SUBCATEGORIA        sku  \
# 0   Bebidas        Aguas       5382
# 1   Bebidas        Aguas  100125864
# 2   Bebidas        Aguas       5745
# 3   Bebidas        Aguas       5566
# 4   Bebidas        Aguas       5370
#
#                                               nombre      marca  precio_lista  \
# 0            Agua Mineral SAN MATEO Sin Gas Bidón 7L  SAN MATEO           8.5
# 1        Agua sin Gas CIELO Botella 2.5L Paquete 6un      CIELO          14.5
# 2        Agua Mineral SAN MATEO Sin Gas Botella 2.5L  SAN MATEO           3.0
# 3  Agua Mineral SAN LUIS Con Gas Botella 625ml Pa...   SAN LUIS           8.3
# 4  Agua Mineral SAN MATEO Con Gas Botella 600ml P...  SAN MATEO           9.0
#
#    precio_final  descuento_monto  descuento_porcentaje  \
# 0           8.5              NaN                   NaN
# 1          14.5              NaN                   NaN
# 2           3.0              NaN                   NaN
# 3           8.3              NaN                   NaN
# 4           9.0              NaN                   NaN
#
#                                         presentacion  disponible  \
# 0            Agua Mineral SAN MATEO Sin Gas Bidón 7L        True
# 1        Agua sin Gas CIELO Botella 2.5L Paquete 6un        True
# 2        Agua Mineral SAN MATEO Sin Gas Botella 2.5L        True
# 3  Agua Mineral SAN LUIS Con Gas Botella 625ml Pa...        True
# 4  Agua Mineral SAN MATEO Con Gas Botella 600ml P...        True
#
#   fecha_scraping     tienda  cantidad_extraida unidad_extraida  \
# 0     2025-10-31  Plaza Vea                7.0               L
# 1     2025-10-31  Plaza Vea                6.0              un
# 2     2025-10-31  Plaza Vea                2.5               L
# 3     2025-10-31  Plaza Vea                6.0              un
# 4     2025-10-31  Plaza Vea                6.0              un
#
#    multiplicador_paquete  cantidad_total marca_extraida  \
# 0                      1             7.0      SAN MATEO
# 1                      1             6.0          CIELO
# 2                      1             2.5      SAN MATEO
# 3                      1             6.0       SAN LUIS
# 4                      1             6.0      SAN MATEO
#
#    precio_por_unidad_estandar                       subclase_inei
# 0                    1.214286  AGUAS MINERALES Y BEBIDAS GASEOSAS
# 1                    2.416667  AGUAS MINERALES Y BEBIDAS GASEOSAS
# 2                    1.200000  AGUAS MINERALES Y BEBIDAS GASEOSAS
# 3                    1.383333  AGUAS MINERALES Y BEBIDAS GASEOSAS
# 4                    1.500000  AGUAS MINERALES Y BEBIDAS GASEOSAS
#
#
# Datos de consolidado_combustibles.xlsx:
#   Distrito                                    Establecimiento  \
# 0    ANCON                                     CENTER GAS SAC
# 1    ANCON        SERVICIOS DE COMBUSTIBLES SANTA FE E.I.R.L.
# 2    ANCON                   ESTACIÓN DE SERVICIOS ANCÓN S.A.
# 3    ANCON  EMPRESA DE TRANSPORTES Y SERVICIOS VIRGEN DE L...
# 4    ANCON                            INVERSIONES RAMSAN EIRL
#
#                                            Dirección  \
# 0  PANAMERICANA NORTE KM 44.5, SUB LOTE A-1 ASOCI...
# 1  AA.HH. LAS PALMERAS MZ. C, LT. 14 (ANTES SERPE...
# 2  PANAMERICANA NORTE KM. 44, URB. SAN JOSE, MZ. ...
# 3    AV. LA FLORIDA CDRA. 12 MIRAMAR . LAS CONCHITAS
# 4                           JR. PEDRO GAREZON N° 500
#
#                         Teléfono Precio de Venta (Soles por galón)  \
# 0  016788937/948581946/981530091                             13.35
# 1  016983211/960690748/996437408                             13.35
# 2            945635871/993487080                              13.6
# 3                      967743212                             13.79
# 4                      934124950                             13.79
#
#   Departamento Provincia     Producto       Fecha  Precio  \
# 0         LIMA      LIMA  DB5 S-50 UV  2025-11-01   13.35
# 1         LIMA      LIMA  DB5 S-50 UV  2025-11-01   13.35
# 2         LIMA      LIMA  DB5 S-50 UV  2025-11-01   13.60
# 3         LIMA      LIMA  DB5 S-50 UV  2025-11-01   13.79
# 4         LIMA      LIMA  DB5 S-50 UV  2025-11-01   13.79
#
#                                           Origen
# 0  data/raw/osinergmin\osinergmin_01_11_2025.csv
# 1  data/raw/osinergmin\osinergmin_01_11_2025.csv
# 2  data/raw/osinergmin\osinergmin_01_11_2025.csv
# 3  data/raw/osinergmin\osinergmin_01_11_2025.csv
# 4  data/raw/osinergmin\osinergmin_01_11_2025.csv
#
#
# Datos de consolidado_educacion.xlsx:
# Empty DataFrame
# Columns: []
# Index: []
#
#
# Datos de consolidado_salud.xlsx:
#    CODIGO                   CATEGORIA  \
# 0   68533  ANTIINFECCIOSOS SISTÉMICOS
# 1   14559  ANTIINFECCIOSOS SISTÉMICOS
# 2   14552  ANTIINFECCIOSOS SISTÉMICOS
# 3  221009  ANTIINFECCIOSOS SISTÉMICOS
# 4  427491  ANTIINFECCIOSOS SISTÉMICOS
#
#                                               NOMBRE  \
# 0              Doxiciclina 100 mg Tableta Recubierta
# 1           Amoxicilina 500 mg Tableta - Caja 100 UN
# 2                          Amoxicilina 500mg Cápsula
# 3                Bactrim Forte 800-160mg Comprimidos
# 4  Amoxicilina - Acido clavulanico 500mg /125mg T...
#
#                   NOMBRE_COMERCIAL CONCENTRACION  CONCENTRACION_NUM  \
# 0                      Doxiciclina        100 mg              100.0
# 1                      Amoxicilina        500 mg              500.0
# 2                      Amoxicilina         500mg              500.0
# 3                Bactrim Forte 800         160mg              160.0
# 4  Amoxicilina - Acido clavulanico   500mg/125mg              500.0
#
#   CONCENTRACION_UNIDAD                       DESCRIPCION  \
# 0                   mg         100 mg Tableta Recubierta
# 1                   mg      500 mg Tableta - Caja 100 UN
# 2                   mg                     500mg Cápsula
# 3                   mg                 160mg Comprimidos
# 4                   mg  500mg/125mg Tabletas recubiertas
#
#                 LABORATORIO  PRESENTACION  ... CANTIDAD_ENVASE  UNIDAD_ENVASE  \
# 0                  AC FARMA   CAJA 100 UN  ...           100.0             un
# 1  INSTITUTO QUIMIOTERAPICO   CAJA 100 UN  ...           100.0             un
# 2                  PORTUGAL   CAJA 100 UN  ...           100.0             un
# 3    ROCHE NACIONAL Q.F.S.A  BLÍSTER 5 UN  ...             5.0             un
# 4                  PORTUGAL    CAJA 10 UN  ...            10.0             un
#
#   PRECIO_LISTA  PRECIO_OFERTA  PRECIO_FINAL  PRECIO_UNITARIO       FECHA  \
# 0         30.0            0.0          30.0             0.30  2025-10-29
# 1         25.0            0.0          25.0             0.25  2025-10-29
# 2         26.0            0.0          26.0             0.26  2025-10-29
# 3          5.0            0.0           5.0             1.00  2025-10-29
# 4         13.0           12.5          12.5             1.25  2025-10-29
#
#                             CLAVE_MATCHING     FUENTE  \
# 0                        doxiciclina_100mg  INKAFARMA
# 1                        amoxicilina_500mg  INKAFARMA
# 2                        amoxicilina_500mg  INKAFARMA
# 3                    bactrimforte800_160mg  INKAFARMA
# 4  amoxicilinaacidoclavulanico_500mg/125mg  INKAFARMA
#
#                SUBCATEGORIA_EST
# 0  ANTIBIÓTICOS/ANTIBACTERIANOS
# 1  ANTIBIÓTICOS/ANTIBACTERIANOS
# 2  ANTIBIÓTICOS/ANTIBACTERIANOS
# 3  ANTIBIÓTICOS/ANTIBACTERIANOS
# 4  ANTIBIÓTICOS/ANTIBACTERIANOS
#
# [5 rows x 21 columns]
#
#
# Datos de consolidado_vivienda.xlsx:
#                                         precio  \
# 0      S/ 2,200 · USD 650 S/ 200 Mantenimiento
# 1                         S/ 9,082 · USD 2,390
# 2      S/ 1,900 · USD 560 S/ 190 Mantenimiento
# 3  S/ 3,100 · USD 209,000 S/ 240 Mantenimiento
# 4      S/ 1,600 · USD 472 S/ 100 Mantenimiento
#
#                                            ubicacion                 titulo  \
# 0  AV LOS FRESNOS 400, LA MOLINA El Remanso, La M...  El Remanso, La Molina
# 1                  Av. Javier Prado San Isidro, Lima       San Isidro, Lima
# 2              Av. San Felipe 1140 Jesús María, Lima      Jesús María, Lima
# 3        PARQUE NACIONES UNIDAS 104 Miraflores, Lima       Miraflores, Lima
# 4                  Av Petit Thouars 1498 Lince, Lima            Lince, Lima
#
#       caracteristicas         area  dormitorios  banos fecha_publicacion  \
# 0  Área de lavandería   98 m² tot.          NaN    NaN        29/10/2025
# 1            Ascensor  190 m² tot.          NaN    NaN        31/10/2025
# 2           Seguridad   55 m² tot.          NaN    NaN        29/10/2025
# 3  Área de lavandería   90 m² tot.          NaN    NaN        28/10/2025
# 4            Ascensor   35 m² tot.          NaN    NaN        28/10/2025
#
#                                                  url  website  ... Ciudad  \
# 0  Departamento en piso 3 sin acensor alquiler de...  urbania  ...   Lima
# 1  Ubicado en la exclusiva zona de embajadas de S...  urbania  ...   Lima
# 2  Precio con cochera 2, 100 soles. Precio sin co...  urbania  ...   Lima
# 3  * lindo departamento reformado junto al parque...  urbania  ...   Lima
# 4  Contacto: Grover Rosas Vela. Solicitar video d...  urbania  ...   Lima
#
#        Tipo      Inmueble Pagina precio_numerico  moneda  area_m2  \
# 0  alquiler  departamento      1            2200     USD       98
# 1  alquiler  departamento      1            9082     USD      190
# 2  alquiler  departamento      1            1900     USD       55
# 3  alquiler  departamento      1            3100     USD       90
# 4  alquiler  departamento      1            1600     USD       35
#
#       distrito  precio_m2 id
# 0    La Molina  22.448980  1
# 1   San Isidro  47.800000  2
# 2  Jesús María  34.545455  3
# 3   Miraflores  34.444444  4
# 4        Lince  45.714286  5
#
# [5 rows x 22 columns]
